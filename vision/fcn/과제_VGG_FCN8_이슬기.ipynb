# %%
import cv2, os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.utils import shuffle
import pandas as pd

# %% [markdown]
# **First, download data from:**
#
# https://drive.google.com/file/d/0B0d9ZiqAgFkiOHR1NTJhWVJMNEU/view
#
# and save the downloaded data1 folder in the current directory.

# %%
dir_data = "dataset1/"
dir_seg = dir_data + "/annotations_prepped_train/"
dir_img = dir_data + "/images_prepped_train/"

# %% [markdown]
# **Visualize a single segmentation image**
#
# In this data, there are 12 segmentation classes and the image is from a driving car.

# %%
## seaborn has white grid by default so I will get rid of this.
sns.set_style("whitegrid", {'axes.grid' : False})


ldseg = np.array(os.listdir(dir_seg))
## pick the first image file
fnm = ldseg[0]
print(fnm)

## read in the original image and segmentation labels
seg = cv2.imread(dir_seg + fnm ) # (360, 480, 3)
img_is = cv2.imread(dir_img + fnm )
print("seg.shape={}, img_is.shape={}".format(seg.shape,img_is.shape))

## Check the number of labels
mi, ma = np.min(seg), np.max(seg)
n_classes = ma - mi + 1
print("minimum seg = {}, maximum seg = {}, Total number of segmentation classes = {}".format(mi,ma, n_classes))

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1,1,1)
ax.imshow(img_is)
ax.set_title("original image")
plt.show()

fig = plt.figure(figsize=(15,10))
for k in range(mi,ma+1):
    ax = fig.add_subplot(3,n_classes/3,k+1)
    ax.imshow((seg == k)*1.0)
    ax.set_title("label = {}".format(k))


plt.show()
# Out:
# 0001TP_008310.png
# seg.shape=(360, 480, 3), img_is.shape=(360, 480, 3)
# minimum seg = 0, maximum seg = 11, Total number of segmentation classes = 12

# %% [markdown]
# **Data preprocessing: Resize image**
#
# To simplify the problem, I will reshape all the images to the same size: (224,224).
# Why (224,224)?
# This is the iamge shape used in VGG and FCN model in this blog uses a network that takes advantage of VGG structure.
# The FCN model becomes easier to explain when the image shape is (224,224).
# However, FCN does not requires the image shape to be (224,224).
#
# Let's visualize how the resizing make the images look like. The images look fine.

# %%
def give_color_to_seg_img(seg,n_classes):
    '''
    seg : (input_width,input_height,3)
    '''
    
    if len(seg.shape)==3:
        seg = seg[:,:,0]
    seg_img = np.zeros( (seg.shape[0],seg.shape[1],3) ).astype('float')
    colors = sns.color_palette("hls", n_classes)
    
    for c in range(n_classes):
        segc = (seg == c)
        seg_img[:,:,0] += (segc*( colors[c][0] ))
        seg_img[:,:,1] += (segc*( colors[c][1] ))
        seg_img[:,:,2] += (segc*( colors[c][2] ))

    return(seg_img)

# %%
input_height , input_width = 224 , 224
output_height , output_width = 224 , 224


ldseg = np.array(os.listdir(dir_seg))
for fnm in ldseg[np.random.choice(len(ldseg),3,replace=False)]:
    fnm = fnm.split(".")[0]
    seg = cv2.imread(dir_seg + fnm + ".png") # (360, 480, 3)
    img_is = cv2.imread(dir_img + fnm + ".png")
    seg_img = give_color_to_seg_img(seg,n_classes)

    fig = plt.figure(figsize=(20,40))
    ax = fig.add_subplot(1,4,1)
    ax.imshow(seg_img)
    
    ax = fig.add_subplot(1,4,2)
    ax.imshow(img_is/255.0)
    ax.set_title("original image {}".format(img_is.shape[:2]))
    
    ax = fig.add_subplot(1,4,3)
    ax.imshow(cv2.resize(seg_img,(input_height , input_width)))
    
    ax = fig.add_subplot(1,4,4)
    ax.imshow(cv2.resize(img_is,(output_height , output_width))/255.0)
    ax.set_title("resized to {}".format((output_height , output_width)))
    plt.show()

# %%
def getImageArr( path , width , height ):
        img = cv2.imread(path, 1)
        img = np.float32(cv2.resize(img, ( width , height ))) / 127.5 - 1
        return img

def getSegmentationArr( path , nClasses ,  width , height  ):

    seg_labels = np.zeros((  height , width  , nClasses ))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, ( width , height ))
    img = img[:, : , 0]

    for c in range(nClasses):
        seg_labels[: , : , c ] = (img == c ).astype(int)
    ##seg_labels = np.reshape(seg_labels, ( width*height,nClasses  ))
    return seg_labels

# %% [markdown]
# Resize all the images. We have 367 images in this dataset

# %%
images = os.listdir(dir_img)
images.sort()
segmentations  = os.listdir(dir_seg)
segmentations.sort()
    
X = []
Y = []
for im , seg in zip(images,segmentations) :
    X.append( getImageArr(dir_img + im , input_width , input_height )  )
    Y.append( getSegmentationArr( dir_seg + seg , n_classes , output_width , output_height )  )

X, Y = np.array(X) , np.array(Y)
print(X.shape,Y.shape)
# Out:
# (367, 224, 224, 3) (367, 224, 224, 12)

# %% [markdown]
# Import Keras and Tensorflow to develop deep learning FCN models

# %%
## Import usual libraries
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
import keras, sys, time, warnings
from keras.models import *
from keras.layers import *
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
print("python {}".format(sys.version))
print("keras version {}".format(keras.__version__)); del keras
print("tensorflow version {}".format(tf.__version__))
# Out:
# python 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0]
# keras version 2.2.5
# tensorflow version 1.12.0

# %%
## location of VGG weights
VGG_Weights_path = "vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %% [markdown]
# **Homework** ->
# Make FCN8 based on FCN16

# %%
def FCN8(nClasses ,  input_height=224, input_width=224):
    ## input_height and width must be devisible by 32 because maxpooling with filter size = (2,2) is operated 5 times,
    ## which makes the input_height and width 2^5 = 32 times smaller
    assert input_height%32 == 0
    assert input_width%32 == 0
    IMAGE_ORDERING =  "channels_last" 

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    
    ## Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x)
    f1 = x
    
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x)
    f2 = x

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x)
    pool3 = x

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x)
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x)## (None, 14, 14, 512) 

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(pool4)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x)
    pool5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x)## (None, 7, 7, 512)

    #x = Flatten(name='flatten')(x)
    #x = Dense(4096, activation='relu', name='fc1')(x)
    # <--> o = ( Conv2D( 4096 , ( 7 , 7 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(4096, activation='relu', name='fc2')(x)
    # <--> o = ( Conv2D( 4096 , ( 1 , 1 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)   
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(1000 , activation='softmax', name='predictions')(x)
    # <--> o = ( Conv2D( nClasses ,  ( 1 , 1 ) ,kernel_initializer='he_normal' , data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    
    vgg  = Model(  img_input , pool5  )
    vgg.load_weights(VGG_Weights_path) ## loading VGG weights for the encoder parts of FCN8
    
    n = 4096
    o = ( Conv2D( n , ( 7 , 7 ) , activation='relu' , padding='same', name="conv6", data_format=IMAGE_ORDERING))(pool5)
    conv7 = ( Conv2D( n , ( 1 , 1 ) , activation='relu' , padding='same', name="conv7", data_format=IMAGE_ORDERING))(o)
    
    
    ## 4 times upsamping for pool4 layer
    conv7_2 = Conv2DTranspose( nClasses , kernel_size=(2,2) ,  strides=(2,2) , use_bias=False, data_format=IMAGE_ORDERING )(conv7)
    ## (None, 224, 224, 10)
    ## 2 times upsampling for pool411
    pool411 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool4_11", data_format=IMAGE_ORDERING))(pool4)
      
    ok = Add(name="add")([pool411, conv7_2])
    conv7_4= Conv2DTranspose( nClasses , kernel_size=(2,2) ,  strides=(2,2) , use_bias=False, data_format=IMAGE_ORDERING )(conv7_2)
    pool311 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool3_11", data_format=IMAGE_ORDERING))(pool3)
        
    okk = Add(name='add2')([pool311, conv7_4])
    
    o = Conv2DTranspose( nClasses , kernel_size=(8,8) ,  strides=(8,8) , use_bias=False, data_format=IMAGE_ORDERING )(okk)
    o = (Activation('softmax'))(o)
    
    model = Model(img_input, o)

    return model

# %%
model = FCN8(nClasses     = n_classes,  
             input_height = 224, 
             input_width  = 224)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv6 (Conv2D)                  (None, 7, 7, 4096)   102764544   block5_pool[0][0]
# __________________________________________________________________________________________________
# conv7 (Conv2D)                  (None, 7, 7, 4096)   16781312    conv6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 14, 14, 12)   196608      conv7[0][0]
# __________________________________________________________________________________________________
# pool3_11 (Conv2D)               (None, 28, 28, 12)   3084        block3_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 28, 28, 12)   576         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# add2 (Add)                      (None, 28, 28, 12)   0           pool3_11[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 224, 224, 12) 9216        add2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 12) 0           conv2d_transpose_3[0][0]
# ==================================================================================================
# Total params: 134,470,028
# Trainable params: 134,470,028
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Split between training and testing data

# %%
train_rate = 0.85
index_train = np.random.choice(X.shape[0],int(X.shape[0]*train_rate),replace=False)
index_test  = list(set(range(X.shape[0])) - set(index_train))
                            
X, Y = shuffle(X,Y)
X_train, y_train = X[index_train],Y[index_train]
X_test, y_test = X[index_test],Y[index_test]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (311, 224, 224, 3) (311, 224, 224, 12)
# (56, 224, 224, 3) (56, 224, 224, 12)

# %% [markdown]
# **Training starts here**

# %%
sgd = optimizers.SGD(lr=1E-2, decay=5**(-4), momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

hist1 = model.fit(X_train,y_train,
                  validation_data=(X_test,y_test),
                  batch_size=32,epochs=250)
# Out:
# Train on 311 samples, validate on 56 samples
# Epoch 1/250
# 311/311 [==============================] - 26s 84ms/step - loss: 2.5739 - acc: 0.0846 - val_loss: 2.4850 - val_acc: 0.0803
# Epoch 2/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4849 - acc: 0.0817 - val_loss: 2.4849 - val_acc: 0.0845
# Epoch 3/250
# 311/311 [==============================] - 7s 24ms/step - loss: 2.4848 - acc: 0.0863 - val_loss: 2.4847 - val_acc: 0.0892
# Epoch 4/250
# 311/311 [==============================] - 7s 24ms/step - loss: 2.4846 - acc: 0.0903 - val_loss: 2.4845 - val_acc: 0.0920
# Epoch 5/250
# 311/311 [==============================] - 7s 24ms/step - loss: 2.4845 - acc: 0.0917 - val_loss: 2.4843 - val_acc: 0.0922
# Epoch 6/250
# 311/311 [==============================] - 7s 24ms/step - loss: 2.4843 - acc: 0.0916 - val_loss: 2.4841 - val_acc: 0.0923
# Epoch 7/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4840 - acc: 0.0919 - val_loss: 2.4838 - val_acc: 0.0930
# Epoch 8/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4837 - acc: 0.0929 - val_loss: 2.4835 - val_acc: 0.0943
# Epoch 9/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4833 - acc: 0.0943 - val_loss: 2.4830 - val_acc: 0.0957
# Epoch 10/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4827 - acc: 0.0956 - val_loss: 2.4822 - val_acc: 0.0972
# Epoch 11/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4818 - acc: 0.0972 - val_loss: 2.4808 - val_acc: 0.0991
# Epoch 12/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4798 - acc: 0.0994 - val_loss: 2.4774 - val_acc: 0.1020
# Epoch 13/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4746 - acc: 0.1032 - val_loss: 2.4680 - val_acc: 0.1083
# Epoch 14/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4616 - acc: 0.1139 - val_loss: 2.4463 - val_acc: 0.1275
# Epoch 15/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.4260 - acc: 0.1381 - val_loss: 2.3752 - val_acc: 0.1683
# Epoch 16/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.3003 - acc: 0.2063 - val_loss: 2.1364 - val_acc: 0.2753
# Epoch 17/250
# 311/311 [==============================] - 8s 24ms/step - loss: 2.0256 - acc: 0.3143 - val_loss: 1.8511 - val_acc: 0.3465
# Epoch 18/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.8527 - acc: 0.3492 - val_loss: 1.8250 - val_acc: 0.3591
# Epoch 19/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.8127 - acc: 0.3697 - val_loss: 1.7610 - val_acc: 0.4016
# Epoch 20/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.7502 - acc: 0.4039 - val_loss: 1.6915 - val_acc: 0.4455
# Epoch 21/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.6476 - acc: 0.4617 - val_loss: 1.5233 - val_acc: 0.4952
# Epoch 22/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.4912 - acc: 0.5206 - val_loss: 1.4071 - val_acc: 0.5609
# Epoch 23/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.3560 - acc: 0.5852 - val_loss: 1.2723 - val_acc: 0.6257
# Epoch 24/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.2590 - acc: 0.6225 - val_loss: 1.2127 - val_acc: 0.6486
# Epoch 25/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.2268 - acc: 0.6284 - val_loss: 1.1753 - val_acc: 0.6530
# Epoch 26/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.1566 - acc: 0.6441 - val_loss: 1.2148 - val_acc: 0.6354
# Epoch 27/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.1268 - acc: 0.6488 - val_loss: 1.1011 - val_acc: 0.6734
# Epoch 28/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.0745 - acc: 0.6619 - val_loss: 1.1055 - val_acc: 0.6681
# Epoch 29/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.0519 - acc: 0.6655 - val_loss: 1.0416 - val_acc: 0.6809
# Epoch 30/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.0391 - acc: 0.6684 - val_loss: 1.0224 - val_acc: 0.6861
# Epoch 31/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.0230 - acc: 0.6719 - val_loss: 1.0232 - val_acc: 0.6907
# Epoch 32/250
# 311/311 [==============================] - 8s 24ms/step - loss: 1.0047 - acc: 0.6763 - val_loss: 0.9912 - val_acc: 0.6926
# Epoch 33/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9880 - acc: 0.6808 - val_loss: 0.9819 - val_acc: 0.6942
# Epoch 34/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9780 - acc: 0.6839 - val_loss: 0.9717 - val_acc: 0.6980
# Epoch 35/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9595 - acc: 0.6881 - val_loss: 0.9699 - val_acc: 0.6985
# Epoch 36/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9834 - acc: 0.6810 - val_loss: 0.9501 - val_acc: 0.7020
# Epoch 37/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9505 - acc: 0.6891 - val_loss: 0.9591 - val_acc: 0.6961
# Epoch 38/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9383 - acc: 0.6935 - val_loss: 0.9487 - val_acc: 0.7033
# Epoch 39/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9385 - acc: 0.6934 - val_loss: 0.9246 - val_acc: 0.7078
# Epoch 40/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.9211 - acc: 0.6979 - val_loss: 0.9332 - val_acc: 0.7044
# Epoch 41/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9422 - acc: 0.6908 - val_loss: 0.9352 - val_acc: 0.7023
# Epoch 42/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.9170 - acc: 0.6984 - val_loss: 0.9152 - val_acc: 0.7120
# Epoch 43/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9022 - acc: 0.7024 - val_loss: 0.9091 - val_acc: 0.7142
# Epoch 44/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9021 - acc: 0.7035 - val_loss: 0.9231 - val_acc: 0.7129
# Epoch 45/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.8920 - acc: 0.7052 - val_loss: 0.9106 - val_acc: 0.7115
# Epoch 46/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.8951 - acc: 0.7047 - val_loss: 0.8840 - val_acc: 0.7208
# Epoch 47/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.9312 - acc: 0.6940 - val_loss: 0.9285 - val_acc: 0.7075
# Epoch 48/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.8888 - acc: 0.7060 - val_loss: 0.8812 - val_acc: 0.7205
# Epoch 49/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.8749 - acc: 0.7113 - val_loss: 0.8900 - val_acc: 0.7219
# Epoch 50/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.8551 - acc: 0.7219 - val_loss: 0.8799 - val_acc: 0.7274
# Epoch 51/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.8527 - acc: 0.7264 - val_loss: 0.8567 - val_acc: 0.7296
# Epoch 52/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.8436 - acc: 0.7307 - val_loss: 0.8924 - val_acc: 0.7214
# Epoch 53/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.8244 - acc: 0.7423 - val_loss: 0.8405 - val_acc: 0.7447
# Epoch 54/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.8219 - acc: 0.7462 - val_loss: 0.8412 - val_acc: 0.7428
# Epoch 55/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.8033 - acc: 0.7586 - val_loss: 0.8292 - val_acc: 0.7497
# Epoch 56/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.7866 - acc: 0.7659 - val_loss: 0.8121 - val_acc: 0.7559
# Epoch 57/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.8027 - acc: 0.7609 - val_loss: 0.9111 - val_acc: 0.7232
# Epoch 58/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.8521 - acc: 0.7471 - val_loss: 0.8472 - val_acc: 0.7464
# Epoch 59/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7909 - acc: 0.7675 - val_loss: 0.7995 - val_acc: 0.7616
# Epoch 60/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.7596 - acc: 0.7771 - val_loss: 0.8125 - val_acc: 0.7595
# Epoch 61/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.7376 - acc: 0.7852 - val_loss: 0.7688 - val_acc: 0.7740
# Epoch 62/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7181 - acc: 0.7918 - val_loss: 0.7965 - val_acc: 0.7615
# Epoch 63/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7205 - acc: 0.7903 - val_loss: 0.7656 - val_acc: 0.7737
# Epoch 64/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.7113 - acc: 0.7929 - val_loss: 0.7570 - val_acc: 0.7796
# Epoch 65/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.7021 - acc: 0.7971 - val_loss: 0.7399 - val_acc: 0.7830
# Epoch 66/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.6964 - acc: 0.7974 - val_loss: 0.7419 - val_acc: 0.7831
# Epoch 67/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6720 - acc: 0.8062 - val_loss: 0.7343 - val_acc: 0.7840
# Epoch 68/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.7045 - acc: 0.7960 - val_loss: 0.7759 - val_acc: 0.7700
# Epoch 69/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6697 - acc: 0.8058 - val_loss: 0.7856 - val_acc: 0.7654
# Epoch 70/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7120 - acc: 0.7918 - val_loss: 0.7348 - val_acc: 0.7836
# Epoch 71/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.6577 - acc: 0.8102 - val_loss: 0.7170 - val_acc: 0.7897
# Epoch 72/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6470 - acc: 0.8139 - val_loss: 0.7388 - val_acc: 0.7833
# Epoch 73/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6399 - acc: 0.8166 - val_loss: 0.7131 - val_acc: 0.7922
# Epoch 74/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6337 - acc: 0.8180 - val_loss: 0.7099 - val_acc: 0.7945
# Epoch 75/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6316 - acc: 0.8192 - val_loss: 0.7195 - val_acc: 0.7895
# Epoch 76/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.6307 - acc: 0.8192 - val_loss: 0.6996 - val_acc: 0.7963
# Epoch 77/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6336 - acc: 0.8189 - val_loss: 0.6918 - val_acc: 0.7985
# Epoch 78/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.6374 - acc: 0.8171 - val_loss: 0.6891 - val_acc: 0.7994
# Epoch 79/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.6309 - acc: 0.8186 - val_loss: 0.6935 - val_acc: 0.7972
# Epoch 80/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5967 - acc: 0.8302 - val_loss: 0.6940 - val_acc: 0.7987
# Epoch 81/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.6003 - acc: 0.8288 - val_loss: 0.6855 - val_acc: 0.8025
# Epoch 82/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.5937 - acc: 0.8309 - val_loss: 0.7685 - val_acc: 0.7793
# Epoch 83/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5977 - acc: 0.8296 - val_loss: 0.6748 - val_acc: 0.8082
# Epoch 84/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5749 - acc: 0.8384 - val_loss: 0.6798 - val_acc: 0.8062
# Epoch 85/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5811 - acc: 0.8361 - val_loss: 0.6718 - val_acc: 0.8085
# Epoch 86/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5678 - acc: 0.8403 - val_loss: 0.6813 - val_acc: 0.8071
# Epoch 87/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5735 - acc: 0.8383 - val_loss: 0.6580 - val_acc: 0.8145
# Epoch 88/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.5508 - acc: 0.8466 - val_loss: 0.6764 - val_acc: 0.8093
# Epoch 89/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.5523 - acc: 0.8459 - val_loss: 0.6615 - val_acc: 0.8149
# Epoch 90/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.6041 - acc: 0.8271 - val_loss: 0.8506 - val_acc: 0.7505
# Epoch 91/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7829 - acc: 0.7763 - val_loss: 0.7345 - val_acc: 0.7820
# Epoch 92/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6174 - acc: 0.8231 - val_loss: 0.6758 - val_acc: 0.8061
# Epoch 93/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.5784 - acc: 0.8370 - val_loss: 0.6560 - val_acc: 0.8143
# Epoch 94/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5538 - acc: 0.8461 - val_loss: 0.6551 - val_acc: 0.8145
# Epoch 95/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.5394 - acc: 0.8508 - val_loss: 0.6509 - val_acc: 0.8172
# Epoch 96/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.5304 - acc: 0.8537 - val_loss: 0.6481 - val_acc: 0.8204
# Epoch 97/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5332 - acc: 0.8523 - val_loss: 0.6525 - val_acc: 0.8191
# Epoch 98/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5194 - acc: 0.8574 - val_loss: 0.6543 - val_acc: 0.8197
# Epoch 99/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.5180 - acc: 0.8579 - val_loss: 0.6463 - val_acc: 0.8214
# Epoch 100/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5163 - acc: 0.8583 - val_loss: 0.6410 - val_acc: 0.8232
# Epoch 101/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.5175 - acc: 0.8583 - val_loss: 0.6348 - val_acc: 0.8250
# Epoch 102/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5173 - acc: 0.8577 - val_loss: 0.6475 - val_acc: 0.8217
# Epoch 103/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5095 - acc: 0.8602 - val_loss: 0.6358 - val_acc: 0.8241
# Epoch 104/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4919 - acc: 0.8663 - val_loss: 0.6379 - val_acc: 0.8254
# Epoch 105/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5055 - acc: 0.8621 - val_loss: 0.6325 - val_acc: 0.8277
# Epoch 106/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4827 - acc: 0.8698 - val_loss: 0.6475 - val_acc: 0.8251
# Epoch 107/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4911 - acc: 0.8663 - val_loss: 0.6508 - val_acc: 0.8241
# Epoch 108/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4829 - acc: 0.8693 - val_loss: 0.6295 - val_acc: 0.8281
# Epoch 109/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4795 - acc: 0.8704 - val_loss: 0.6307 - val_acc: 0.8286
# Epoch 110/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4718 - acc: 0.8730 - val_loss: 0.6391 - val_acc: 0.8269
# Epoch 111/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4741 - acc: 0.8715 - val_loss: 0.6499 - val_acc: 0.8252
# Epoch 112/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4767 - acc: 0.8710 - val_loss: 0.6375 - val_acc: 0.8266
# Epoch 113/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4697 - acc: 0.8732 - val_loss: 0.6323 - val_acc: 0.8273
# Epoch 114/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4704 - acc: 0.8729 - val_loss: 0.6322 - val_acc: 0.8285
# Epoch 115/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4704 - acc: 0.8722 - val_loss: 0.6372 - val_acc: 0.8265
# Epoch 116/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4652 - acc: 0.8744 - val_loss: 0.6303 - val_acc: 0.8286
# Epoch 117/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4607 - acc: 0.8755 - val_loss: 0.6404 - val_acc: 0.8262
# Epoch 118/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4592 - acc: 0.8763 - val_loss: 0.6223 - val_acc: 0.8318
# Epoch 119/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4509 - acc: 0.8790 - val_loss: 0.6255 - val_acc: 0.8313
# Epoch 120/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4572 - acc: 0.8763 - val_loss: 0.6249 - val_acc: 0.8298
# Epoch 121/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4402 - acc: 0.8822 - val_loss: 0.6281 - val_acc: 0.8311
# Epoch 122/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4478 - acc: 0.8796 - val_loss: 0.6377 - val_acc: 0.8271
# Epoch 123/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4400 - acc: 0.8820 - val_loss: 0.6345 - val_acc: 0.8307
# Epoch 124/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4544 - acc: 0.8768 - val_loss: 0.6434 - val_acc: 0.8241
# Epoch 125/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4575 - acc: 0.8757 - val_loss: 0.6224 - val_acc: 0.8327
# Epoch 126/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4467 - acc: 0.8795 - val_loss: 0.6303 - val_acc: 0.8325
# Epoch 127/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4325 - acc: 0.8841 - val_loss: 0.6236 - val_acc: 0.8332
# Epoch 128/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4295 - acc: 0.8848 - val_loss: 0.6334 - val_acc: 0.8317
# Epoch 129/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4330 - acc: 0.8834 - val_loss: 0.6242 - val_acc: 0.8324
# Epoch 130/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4187 - acc: 0.8880 - val_loss: 0.6303 - val_acc: 0.8335
# Epoch 131/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4332 - acc: 0.8833 - val_loss: 0.6226 - val_acc: 0.8329
# Epoch 132/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4176 - acc: 0.8879 - val_loss: 0.6236 - val_acc: 0.8336
# Epoch 133/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4191 - acc: 0.8876 - val_loss: 0.6457 - val_acc: 0.8276
# Epoch 134/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4207 - acc: 0.8867 - val_loss: 0.6279 - val_acc: 0.8328
# Epoch 135/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4134 - acc: 0.8889 - val_loss: 0.6386 - val_acc: 0.8317
# Epoch 136/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4143 - acc: 0.8883 - val_loss: 0.6527 - val_acc: 0.8287
# Epoch 137/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4366 - acc: 0.8815 - val_loss: 0.6257 - val_acc: 0.8338
# Epoch 138/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4104 - acc: 0.8897 - val_loss: 0.6376 - val_acc: 0.8299
# Epoch 139/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4139 - acc: 0.8883 - val_loss: 0.6495 - val_acc: 0.8253
# Epoch 140/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4090 - acc: 0.8899 - val_loss: 0.6367 - val_acc: 0.8310
# Epoch 141/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4084 - acc: 0.8898 - val_loss: 0.6343 - val_acc: 0.8312
# Epoch 142/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4032 - acc: 0.8916 - val_loss: 0.6325 - val_acc: 0.8333
# Epoch 143/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3978 - acc: 0.8932 - val_loss: 0.6434 - val_acc: 0.8302
# Epoch 144/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4100 - acc: 0.8888 - val_loss: 0.6450 - val_acc: 0.8289
# Epoch 145/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4142 - acc: 0.8879 - val_loss: 0.6322 - val_acc: 0.8329
# Epoch 146/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4038 - acc: 0.8912 - val_loss: 0.6285 - val_acc: 0.8346
# Epoch 147/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3934 - acc: 0.8941 - val_loss: 0.6370 - val_acc: 0.8325
# Epoch 148/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4045 - acc: 0.8905 - val_loss: 0.6476 - val_acc: 0.8316
# Epoch 149/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.4052 - acc: 0.8902 - val_loss: 0.6257 - val_acc: 0.8343
# Epoch 150/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3905 - acc: 0.8946 - val_loss: 0.6354 - val_acc: 0.8338
# Epoch 151/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3916 - acc: 0.8942 - val_loss: 0.6383 - val_acc: 0.8341
# Epoch 152/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3892 - acc: 0.8948 - val_loss: 0.6372 - val_acc: 0.8335
# Epoch 153/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3946 - acc: 0.8929 - val_loss: 0.6388 - val_acc: 0.8310
# Epoch 154/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3943 - acc: 0.8929 - val_loss: 0.6417 - val_acc: 0.8319
# Epoch 155/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3915 - acc: 0.8937 - val_loss: 0.6389 - val_acc: 0.8327
# Epoch 156/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3835 - acc: 0.8963 - val_loss: 0.6385 - val_acc: 0.8338
# Epoch 157/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3893 - acc: 0.8941 - val_loss: 0.6607 - val_acc: 0.8263
# Epoch 158/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3988 - acc: 0.8913 - val_loss: 0.6513 - val_acc: 0.8285
# Epoch 159/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3908 - acc: 0.8940 - val_loss: 0.6351 - val_acc: 0.8343
# Epoch 160/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3808 - acc: 0.8969 - val_loss: 0.6348 - val_acc: 0.8349
# Epoch 161/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3764 - acc: 0.8982 - val_loss: 0.6463 - val_acc: 0.8334
# Epoch 162/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3773 - acc: 0.8979 - val_loss: 0.6424 - val_acc: 0.8328
# Epoch 163/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3786 - acc: 0.8974 - val_loss: 0.6503 - val_acc: 0.8322
# Epoch 164/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3791 - acc: 0.8972 - val_loss: 0.6521 - val_acc: 0.8304
# Epoch 165/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3774 - acc: 0.8976 - val_loss: 0.6428 - val_acc: 0.8336
# Epoch 166/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3757 - acc: 0.8979 - val_loss: 0.6384 - val_acc: 0.8345
# Epoch 167/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3703 - acc: 0.8996 - val_loss: 0.6509 - val_acc: 0.8314
# Epoch 168/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3933 - acc: 0.8922 - val_loss: 0.6436 - val_acc: 0.8303
# Epoch 169/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3836 - acc: 0.8953 - val_loss: 0.6383 - val_acc: 0.8349
# Epoch 170/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3701 - acc: 0.8996 - val_loss: 0.6406 - val_acc: 0.8348
# Epoch 171/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3723 - acc: 0.8987 - val_loss: 0.6439 - val_acc: 0.8337
# Epoch 172/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3712 - acc: 0.8991 - val_loss: 0.6508 - val_acc: 0.8322
# Epoch 173/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3668 - acc: 0.9004 - val_loss: 0.6444 - val_acc: 0.8347
# Epoch 174/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3675 - acc: 0.9001 - val_loss: 0.6531 - val_acc: 0.8324
# Epoch 175/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3704 - acc: 0.8991 - val_loss: 0.6689 - val_acc: 0.8280
# Epoch 176/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3743 - acc: 0.8979 - val_loss: 0.6476 - val_acc: 0.8347
# Epoch 177/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3624 - acc: 0.9017 - val_loss: 0.6467 - val_acc: 0.8347
# Epoch 178/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3649 - acc: 0.9007 - val_loss: 0.6550 - val_acc: 0.8331
# Epoch 179/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3632 - acc: 0.9012 - val_loss: 0.6537 - val_acc: 0.8333
# Epoch 180/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3806 - acc: 0.8955 - val_loss: 0.6548 - val_acc: 0.8322
# Epoch 181/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3656 - acc: 0.9002 - val_loss: 0.6467 - val_acc: 0.8347
# Epoch 182/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3598 - acc: 0.9021 - val_loss: 0.6501 - val_acc: 0.8329
# Epoch 183/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3602 - acc: 0.9020 - val_loss: 0.6531 - val_acc: 0.8336
# Epoch 184/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3611 - acc: 0.9015 - val_loss: 0.6612 - val_acc: 0.8325
# Epoch 185/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3748 - acc: 0.8971 - val_loss: 0.6454 - val_acc: 0.8343
# Epoch 186/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3679 - acc: 0.8991 - val_loss: 0.6460 - val_acc: 0.8344
# Epoch 187/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3560 - acc: 0.9033 - val_loss: 0.6516 - val_acc: 0.8341
# Epoch 188/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3542 - acc: 0.9038 - val_loss: 0.6561 - val_acc: 0.8334
# Epoch 189/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3545 - acc: 0.9034 - val_loss: 0.6585 - val_acc: 0.8332
# Epoch 190/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3561 - acc: 0.9030 - val_loss: 0.6585 - val_acc: 0.8329
# Epoch 191/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3559 - acc: 0.9031 - val_loss: 0.6652 - val_acc: 0.8327
# Epoch 192/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3580 - acc: 0.9022 - val_loss: 0.6596 - val_acc: 0.8331
# Epoch 193/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3524 - acc: 0.9042 - val_loss: 0.6643 - val_acc: 0.8320
# Epoch 194/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3541 - acc: 0.9035 - val_loss: 0.6701 - val_acc: 0.8309
# Epoch 195/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3593 - acc: 0.9017 - val_loss: 0.6622 - val_acc: 0.8319
# Epoch 196/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3569 - acc: 0.9023 - val_loss: 0.6595 - val_acc: 0.8342
# Epoch 197/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3490 - acc: 0.9052 - val_loss: 0.6666 - val_acc: 0.8326
# Epoch 198/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3534 - acc: 0.9035 - val_loss: 0.6648 - val_acc: 0.8329
# Epoch 199/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3516 - acc: 0.9040 - val_loss: 0.6683 - val_acc: 0.8332
# Epoch 200/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3517 - acc: 0.9039 - val_loss: 0.6660 - val_acc: 0.8334
# Epoch 201/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3472 - acc: 0.9056 - val_loss: 0.6658 - val_acc: 0.8331
# Epoch 202/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3494 - acc: 0.9048 - val_loss: 0.6648 - val_acc: 0.8328
# Epoch 203/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3474 - acc: 0.9055 - val_loss: 0.6719 - val_acc: 0.8330
# Epoch 204/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3465 - acc: 0.9057 - val_loss: 0.6672 - val_acc: 0.8332
# Epoch 205/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3443 - acc: 0.9065 - val_loss: 0.6742 - val_acc: 0.8317
# Epoch 206/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3569 - acc: 0.9020 - val_loss: 0.6625 - val_acc: 0.8332
# Epoch 207/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3438 - acc: 0.9067 - val_loss: 0.6697 - val_acc: 0.8327
# Epoch 208/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3431 - acc: 0.9069 - val_loss: 0.6706 - val_acc: 0.8333
# Epoch 209/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3447 - acc: 0.9064 - val_loss: 0.6695 - val_acc: 0.8330
# Epoch 210/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3419 - acc: 0.9072 - val_loss: 0.6732 - val_acc: 0.8326
# Epoch 211/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3429 - acc: 0.9068 - val_loss: 0.6738 - val_acc: 0.8329
# Epoch 212/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3406 - acc: 0.9076 - val_loss: 0.6756 - val_acc: 0.8328
# Epoch 213/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3442 - acc: 0.9062 - val_loss: 0.6819 - val_acc: 0.8313
# Epoch 214/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3454 - acc: 0.9058 - val_loss: 0.6735 - val_acc: 0.8325
# Epoch 215/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3430 - acc: 0.9066 - val_loss: 0.6749 - val_acc: 0.8331
# Epoch 216/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3395 - acc: 0.9078 - val_loss: 0.6845 - val_acc: 0.8316
# Epoch 217/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3444 - acc: 0.9061 - val_loss: 0.6863 - val_acc: 0.8305
# Epoch 218/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3396 - acc: 0.9078 - val_loss: 0.6772 - val_acc: 0.8327
# Epoch 219/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3371 - acc: 0.9085 - val_loss: 0.6836 - val_acc: 0.8321
# Epoch 220/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3410 - acc: 0.9072 - val_loss: 0.6900 - val_acc: 0.8299
# Epoch 221/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3400 - acc: 0.9075 - val_loss: 0.6778 - val_acc: 0.8321
# Epoch 222/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3354 - acc: 0.9090 - val_loss: 0.6802 - val_acc: 0.8324
# Epoch 223/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3349 - acc: 0.9092 - val_loss: 0.6817 - val_acc: 0.8322
# Epoch 224/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3363 - acc: 0.9087 - val_loss: 0.6894 - val_acc: 0.8311
# Epoch 225/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3445 - acc: 0.9057 - val_loss: 0.6881 - val_acc: 0.8300
# Epoch 226/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3412 - acc: 0.9069 - val_loss: 0.6770 - val_acc: 0.8326
# Epoch 227/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3328 - acc: 0.9098 - val_loss: 0.6870 - val_acc: 0.8298
# Epoch 228/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3464 - acc: 0.9051 - val_loss: 0.6861 - val_acc: 0.8321
# Epoch 229/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3396 - acc: 0.9075 - val_loss: 0.6812 - val_acc: 0.8316
# Epoch 230/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3319 - acc: 0.9101 - val_loss: 0.6819 - val_acc: 0.8325
# Epoch 231/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3296 - acc: 0.9107 - val_loss: 0.6852 - val_acc: 0.8323
# Epoch 232/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3287 - acc: 0.9110 - val_loss: 0.6898 - val_acc: 0.8325
# Epoch 233/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3329 - acc: 0.9094 - val_loss: 0.6945 - val_acc: 0.8313
# Epoch 234/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3330 - acc: 0.9091 - val_loss: 0.6879 - val_acc: 0.8321
# Epoch 235/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3309 - acc: 0.9099 - val_loss: 0.6947 - val_acc: 0.8299
# Epoch 236/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3328 - acc: 0.9093 - val_loss: 0.6911 - val_acc: 0.8317
# Epoch 237/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3289 - acc: 0.9106 - val_loss: 0.6920 - val_acc: 0.8317
# Epoch 238/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3290 - acc: 0.9105 - val_loss: 0.6932 - val_acc: 0.8321
# Epoch 239/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3272 - acc: 0.9112 - val_loss: 0.6960 - val_acc: 0.8316
# Epoch 240/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3296 - acc: 0.9100 - val_loss: 0.6969 - val_acc: 0.8311
# Epoch 241/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3274 - acc: 0.9109 - val_loss: 0.6952 - val_acc: 0.8312
# Epoch 242/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3283 - acc: 0.9106 - val_loss: 0.6996 - val_acc: 0.8304
# Epoch 243/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3269 - acc: 0.9111 - val_loss: 0.6939 - val_acc: 0.8312
# Epoch 244/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3257 - acc: 0.9115 - val_loss: 0.7004 - val_acc: 0.8306
# Epoch 245/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3269 - acc: 0.9110 - val_loss: 0.6981 - val_acc: 0.8313
# Epoch 246/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3266 - acc: 0.9110 - val_loss: 0.7040 - val_acc: 0.8298
# Epoch 247/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3298 - acc: 0.9098 - val_loss: 0.6971 - val_acc: 0.8303
# Epoch 248/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3248 - acc: 0.9116 - val_loss: 0.7002 - val_acc: 0.8315
# Epoch 249/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3232 - acc: 0.9121 - val_loss: 0.7021 - val_acc: 0.8315
# Epoch 250/250
# 311/311 [==============================] - 8s 24ms/step - loss: 0.3238 - acc: 0.9118 - val_loss: 0.7053 - val_acc: 0.8312

# %% [markdown]
# Plot the change in loss over epochs

# %%
for key in ['loss', 'val_loss']:
    plt.plot(hist1.history[key],label=key)
plt.legend()
plt.show()

# %% [markdown]
# Calculate intersection over union for each segmentation class

# %%
y_pred = model.predict(X_test)
y_predi = np.argmax(y_pred, axis=3)
y_testi = np.argmax(y_test, axis=3)
print(y_testi.shape,y_predi.shape)
# Out:
# (56, 224, 224) (56, 224, 224)

# %%
def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)

    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi==c) )
        FP = np.sum( (Yi != c)&(y_predi==c) )
        FN = np.sum( (Yi == c)&(y_predi != c)) 
        IoU = TP/float(TP + FP + FN)
        print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))

# %%
IoU(y_testi,y_predi)
# Out:
# class 00: #TP=390197, #FP= 50908, #FN=38344, IoU=0.814
# class 01: #TP=609350, #FP=122382, #FN=81443, IoU=0.749
# class 02: #TP=    22, #FP=   530, #FN=34032, IoU=0.001
# class 03: #TP=876868, #FP= 62081, #FN=44463, IoU=0.892
# class 04: #TP= 82605, #FP= 36719, #FN=57342, IoU=0.468
# class 05: #TP=159988, #FP= 81638, #FN=49828, IoU=0.549
# class 06: #TP=  2621, #FP= 10955, #FN=33330, IoU=0.056
# class 07: #TP= 19602, #FP= 11729, #FN=20997, IoU=0.375
# class 08: #TP=125601, #FP= 53980, #FN=39196, IoU=0.574
# class 09: #TP=    23, #FP=   640, #FN=21508, IoU=0.001
# class 10: #TP=   125, #FP=   515, #FN=15810, IoU=0.008
# class 11: #TP= 68458, #FP= 42319, #FN=38103, IoU=0.460
# _________________
# Mean IoU: 0.412

# %% [markdown]
# **Visualize the model performance**
#
#
# Looks reasonable!

# %%
shape = (224,224)
n_classes= 10

for i in range(10):
    img_is  = (X_test[i] + 1)*(255.0/2)
    seg = y_predi[i]
    segtest = y_testi[i]

    fig = plt.figure(figsize=(10,30))    
    ax = fig.add_subplot(1,3,1)
    ax.imshow(img_is/255.0)
    ax.set_title("original")
    
    ax = fig.add_subplot(1,3,2)
    ax.imshow(give_color_to_seg_img(seg,n_classes))
    ax.set_title("predicted class")
    
    ax = fig.add_subplot(1,3,3)
    ax.imshow(give_color_to_seg_img(segtest,n_classes))
    ax.set_title("true class")
    plt.show()
